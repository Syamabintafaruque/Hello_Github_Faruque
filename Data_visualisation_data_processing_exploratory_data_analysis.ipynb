# %% [markdown]
# <a href="https://colab.research.google.com/github/Syamabintafaruque/Hello_Github_Faruque/blob/main/Data_visualisation_data_processing_exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : SYAMA BINTA FARUQUE
#
# ID : 20231084
#
# Homework_03 # Data Visualization, Data Preprocessing and Exploratory Data Analysis

# %% [markdown]
# Answer of one cars dataset (Audi, BMW, Ford, Hyundai, Skoda, VW) for the tasks (1 – 10):

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/bmw.csv')

# %%
# 1. Create a Pie Chart and a barplot for any categorical variable. Compare which plot is better and why? Use markdown cells to write your explanations.
import pandas as pd
import matplotlib.pyplot as plt

# x = df["year"].unique()
# y = []
# for i in x:
#   count = df.loc[df['year'] == i, 'price'].count()
#   y.append((df.loc[df['year'] == i, 'price'].sum())/count)

# plt.pie(y,labels = x)
# plt.show()
# plt.bar(x,y)


x = df["transmission"].unique()
y = []
for i in x:
  count = df.loc[df['transmission'] == i, 'price'].count()
  y.append((df.loc[df['transmission'] == i, 'price'].sum())/count)

plt.pie(y,labels = x)
plt.show()
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Explanation : I think baplot is better than pie chart.
#
# Because above the two diagrams, we can see:-
#
# In price against transmission barplot , automatic, manual and semi-auto transmissions are showing their clear price by 3 bars.
#
# But the othr hand, in Pie chart we can't visualize the price against transmission.

# %%
# 2. Create Two scatterplots with numeric columns.
import matplotlib.pyplot as plt
import pandas as pd
path ="/content/drive/MyDrive/audi.csv"
df = pd.read_csv(path)
x = df["mpg"]
y = df["mileage"]


plt.scatter(x,y,s = 0.5)
plt.xlabel("mpg")
plt.ylabel("mileage")
plt.show()

x = df["price"]
y = df["mileage"]


plt.scatter(y,x,s = 0.5)
plt.xlabel("price")
plt.ylabel("mileage")
plt.show()

# %%
# 3. Create Two regression plots with numeric columns.
import seaborn as sns

sns.regplot(x=df.mpg,y=df.mileage,line_kws={"color": "red"})
# Out:
# <Axes: xlabel='mpg', ylabel='mileage'>

# %% [markdown]
# Above regression plot is based on mileage against mpg.

# %%
sns.regplot(x=df.price,y=df.mileage,line_kws={"color": "red"})
# Out:
# <Axes: xlabel='price', ylabel='mileage'>

# %% [markdown]
# Above regression plot with two numeric columns-mileage vs price.

# %%
# 4. Create a Pair plot with numeric columns.
sns.pairplot(df,hue="transmission")

# %%
# 5. For the Scatter plot, Regression Plot, and Pair Plot, add a categorical column as hue if you think it's important.

sns.scatterplot(x = df.mpg,y = df.mileage,data=df, hue = 'transmission')
# Out:
# <Axes: xlabel='mpg', ylabel='mileage'>

# %%
# 6. Make sure you have a proper title, xlabel, ylabel, xticks, yticks, and figure size which will represent an example of good data visualization.
import seaborn as sns
sns.regplot(x=df.price,y=df.mileage,line_kws={"color": "red"})
sns.scatterplot(x = df.price,y = df.mileage,data=df, hue = 'transmission')
plt.title("Mileage against Price")
# Out:
# Text(0.5, 1.0, 'Mileage against Price')

# %%
# 8. Create boxplot or violin plot (one or more) and histogram (one or more) with the numeric columns.
# Add a categorical column as x-axis or hue if you think it's important. Explain which chart is better boxplot or violinplot?

import seaborn as sns
options = [2016, 2017,2018,2019,2020]
dt = df.loc[df['year'].isin(options)]

sns.boxplot(x=dt.year, y=dt.price, data=dt)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %% [markdown]
# Above we can see a price vs year boxplot.

# %%
import numpy as np
sns.set_style('whitegrid')
sns.violinplot(x=dt.year, y=dt.price, data=dt)
y = dt['price'].unique()
plt.yticks(np.arange(0, max(y)+1, 5000))
plt.show()

# %% [markdown]
# Above we can see a plot price vs year which is named violin plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = df["engineSize"].unique()
y = []
for i in x:
  count = df['engineSize'].value_counts()[i]
  y.append(count)

engS = df['engineSize'].unique()
sns.histplot(x=df.engineSize, data=df)
plt.title("Count against engineSize")
plt.xticks(np.arange(min(engS), max(engS)+1, 0.5))
plt.yticks(np.arange(0, max(y)+1, 500))

plt.figure(figsize=(5,3))
plt.show()

# %% [markdown]
# Above we can see a diagram of count against engineSize which is named histogram.

# %%
# 9. Make sure you have a proper title, xlabel, ylabel, xticks, yticks, and figure size which will representan example of good data visualization.

x = df["model"].unique()
y = []
for i in x:
  count = df['model'].value_counts()[i]
  y.append(count)
sns.histplot(x=df.model)
plt.title("Count against model")
plt.yticks(np.arange(0, max(y)+1, 250))

fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(10)

plt.show()

# %%
x = df["transmission"].unique()
y = []
for i in x:
  count = df['transmission'].value_counts()[i]
  y.append(count)
sns.histplot(x=df.transmission)
plt.title("Count against transmission")
plt.yticks(np.arange(0, max(y)+1, 250))

fig = plt.figure()
fig.set_figheight(2)
fig.set_figwidth(2)
plt.rcParams['figure.figsize'] = (6.4, 4.8)

plt.show()

# %%
import pandas as pd
path ="/content/drive/MyDrive/audi.csv"

# %%
# 10. Perform Exploratory Data Analysis (EDA) using groupby/pivot_table and barplot (total 9 barplots),based on model, transmission, and fuelType,
# a) What are the top 5 selling car models/transmission/fuelType in the dataset?
# b) What's the average selling price of the top 5 selling car models/transmission/fuelType?
# c) What's the total sale of the top 5 selling car models/transmission/fuelType?

import pandas as pd
import matplotlib.pyplot as plt
# Top 5 selling car models
top_5_models = df['model'].value_counts().head(5)

# Top 5 selling transmission types
top_5_transmissions = df['transmission'].value_counts().head(5)

# Top 5 selling fuel types
top_5_fuel_types = df['fuelType'].value_counts().head(5)

# Average selling price of top 5 car models
avg_price_models = df.groupby('model')['price'].mean().loc[top_5_models.index]

# Average selling price of top 5 transmission types
avg_price_transmissions = df.groupby('transmission')['price'].mean().loc[top_5_transmissions.index]

# Average selling price of top 5 fuel types
avg_price_fuel_types = df.groupby('fuelType')['price'].mean().loc[top_5_fuel_types.index]

# Total sale of top 5 car models
total_sale_models = df.groupby('model')['price'].sum().loc[top_5_models.index]

# Total sale of top 5 transmission types
total_sale_transmissions = df.groupby('transmission')['price'].sum().loc[top_5_transmissions.index]

# Total sale of top 5 fuel types
total_sale_fuel_types = df.groupby('fuelType')['price'].sum().loc[top_5_fuel_types.index]

# Plotting barplots
plt.figure(figsize=(12, 8))

# Top 5 selling car models
plt.subplot(3, 3, 1)
top_5_models.plot(kind='bar')
plt.title('Top 5 Selling Car Models')
plt.xlabel('Car Models')
plt.ylabel('Number of Sales')

# Average selling price of top 5 car models
plt.subplot(3, 3, 2)
avg_price_models.plot(kind='bar')
plt.title('Average Selling Price of Top 5 Car Models')
plt.xlabel('Car Models')
plt.ylabel('Average Selling Price')

# Total sale of top 5 car models
plt.subplot(3, 3, 3)
total_sale_models.plot(kind='bar')
plt.title('Total Sale of Top 5 Car Models')
plt.xlabel('Car Models')
plt.ylabel('Total Sale')

# Top 5 selling transmission types
plt.subplot(3, 3, 4)
top_5_transmissions.plot(kind='bar')
plt.title('Top 5 Selling Transmission Types')
plt.xlabel('Transmission Types')
plt.ylabel('Number of Sales')

# Average selling price of top 5 transmission types
plt.subplot(3, 3, 5)
avg_price_transmissions.plot(kind='bar')
plt.title('Average Selling Price of Top 5 Transmission Types')
plt.xlabel('Transmission Types')
plt.ylabel('Average Selling Price')

# Total sale of top 5 transmission types
plt.subplot(3, 3, 6)
total_sale_transmissions.plot(kind='bar')
plt.title('Total Sale of Top 5 Transmission Types')
plt.xlabel('Transmission Types')
plt.ylabel('Total Sale')

# Top 5 selling fuel types
plt.subplot(3, 3, 7)
top_5_fuel_types.plot(kind='bar')
plt.title('Top 5 Selling Fuel Types')
plt.xlabel('Fuel Types')
plt.ylabel('Number of Sales')

# Average selling price of top 5 fuel types
plt.subplot(3, 3, 8)
avg_price_fuel_types.plot(kind='bar')
plt.title('Average Selling Price of Top 5 Fuel Types')
plt.xlabel('Fuel Types')
plt.ylabel('Average Selling Price')

# Total sale of top 5 fuel types
plt.subplot(3, 3, 9)
total_sale_fuel_types.plot(kind='bar')
plt.title('Total Sale of Top 5 Fuel Types')
plt.xlabel('Fuel Types')
plt.ylabel('Total Sale')

plt.tight_layout()
plt.show()

# %% [markdown]
# Import the ‘ODI_cricket.xlsx’ file ‘bowler’ sheet in your notebook for the tasks (11 – 26)

# %%
# 11. Display the first 10 rows and last 3 rows of the dataframe.

# Display the first 10 rows
import pandas as pd

xls = pd.ExcelFile("/content/drive/MyDrive/ODI_cricket.xlsx")
df1 = pd.read_excel(xls, 'batsman')
df2 = pd.read_excel(xls, 'bowler')
df2.head(10)
# Out:
#                          Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1             Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2            Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
# 5       SM Pollock (Afr/ICC/SA)  1996-2008  303   297  15712   9631   393
# 6          GD McGrath (AUS/ICC)  1993-2007  250   248  12970   8391   381
# 7                   B Lee (AUS)  2000-2012  221   217  11185   8877   380
# 8               SL Malinga (SL)  2004-2019  226   220  10936   9760   338
# 9         A Kumble (Asia/INDIA)  1990-2007  271   265  14496  10412   337
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# ...

# %%
# last 3 rows of the dataframe.
df2.tail(3)
# Out:
#                Player       Span  Mat  Inns  Balls  Runs  Wkts    Ave  Econ  \
# 74  Rashid Khan (AFG)  2015-2022   80    76   4074  2821   151  18.68  4.15
# 75  UDU Chandana (SL)  1994-2007  147   136   6142  4818   151  31.90  4.70
# 76   R Ashwin (INDIA)  2010-2022  113   111   6141  5058   151  33.49  4.94
#
#       SR  4  5
# 74  26.9  5  4
# 75  40.6  4  1
# 76  40.6  1  0

# %%
# 12. Create a markdown cell and explain the meaning of each column.
df2.columns
# Out:
# Index(['Player',   'Span',    'Mat',   'Inns',  'Balls',   'Runs',   'Wkts',
#           'Ave',   'Econ',     'SR',        4,        5],
#       dtype='object')

# %% [markdown]
# Player--> Name of player(bowler) and in which team he played for cricket.
#
# Span--> Period of time of a player(bowler) playing cricket.
#
# Mat--> how many matches a player(bowler) played for cricket.
#
# Inns--> Innings
#
# Balls--> Total bowlng of a bowler.
#
# Runs--> Total runs of a bowler.
#
# wkts--> Total wickets a bowler took.
#
# Ave --> Average.
#
# Econ--> Economy.
#
# SR--> Strike rates.
#
# 4--> How many 4 wickets took a bowler.
#
# 5--> How many 5 wickets took a bowler.

# %%
# 13. find the number of rows and columns in the dataframe.
shape = df2.shape
shape
# Out:
# (77, 12)

# %%
# 14. find the data statistics and check for the data types.
# find the data statistics
des = df2.describe()
des
# Out:
#               Mat        Inns         Balls          Runs        Wkts  \
# count   77.000000   77.000000     77.000000     77.000000   77.000000
# mean   194.402597  181.194805   8839.402597   6671.714286  233.805195
# std     82.485606   67.958393   3316.055457   2245.839029   84.406603
# min     80.000000   76.000000   4074.000000   2821.000000  151.000000
# 25%    136.000000  128.000000   6182.000000   5058.000000  173.000000
# 50%    170.000000  164.000000   8054.000000   6192.000000  199.000000
# 75%    227.000000  218.000000  10750.000000   8021.000000  272.000000
# max    463.000000  372.000000  18811.000000  13632.000000  534.000000
#
#              Ave       Econ         SR          4          5
# count  77.000000  77.000000  77.000000  77.000000  77.000000
# mean   28.958052   4.596753  37.909091   6.350649   2.870130
# std     4.826768   0.515814   6.060901   3.556929   2.530606
# min    18.680000   3.300000  26.100000   1.000000   0.000000
# ...

# %%
# check for the data types.
typ = df2.dtypes
typ
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# Balls       int64
# Runs        int64
# Wkts        int64
# Ave       float64
# Econ      float64
# SR        float64
# 4           int64
# 5           int64
# dtype: object

# %%
# 15. Are there any missing values present in the dataset?
df2.isnull().values.any()
# Out:
# False

# %%
# 16. Rename the column names appropriately.
col = {"Player":"Player(Team)","Span":"Period","Mat":"Matches","Inns":"Innings","Balls":"Balls","Runs":"Runs","Wkts":"Wickets","Ave":"Average","Econ":"Economy","SR":"Strike Rate","Number of 4s":"4 Wickets","Numer of 5s":"5 Wickets"}
df2.rename(columns=col, inplace = True)
df2.columns
# Out:
# Index(['Player(Team)', 'Period', 'Matches', 'Innings', 'Balls', 'Runs',
#        'Wickets', 'Average', 'Economy', 'Strike Rate', '4 Wickets',
#        '5 Wickets'],
#       dtype='object')

# %%
# 17. How many players played for ICC?
count = df2["Player(Team)"].str.contains("ICC").sum()
count
# Out:
# 77

# %%
# 18. How many different countries are present in this dataset?
new = df2["Player(Team)"].str.split("(", n = 1, expand = True)
niu = new[1].str.split(")", n = 1, expand = True)
new2 = niu[0].str.split("/", expand = True)
print(new2)
c = new2[0].unique()
c1 = set(c.flatten())
print(c1)
c = new2[1].unique()
c2 = set(c.flatten())
print(c2)
c = new2[2].unique()
c3 = set(c.flatten())
print(c3)
c4 = c1.union(c2)
c5 = c4.union(c3)
print(c5)
print(len(c5)-1)
# Out:
#         0     1     2
# 0    Asia   ICC    SL
# 1     PAK  None  None
# 2     PAK  None  None
# 3    Asia    SL  None
# 4    Asia   ICC   PAK
# ..    ...   ...   ...
# 72  INDIA  None  None
# 73     SL  None  None
# 74    AFG  None  None
# 75     SL  None  None
# 76  INDIA  None  None
#
# [77 rows x 3 columns]
# {'INDIA', 'BAN', 'NZ', 'ENG', 'SA', 'AFG', 'WI', 'PAK', 'Afr', 'SL', 'ICC', 'Asia', 'AUS'}
# {'ZIM', 'INDIA', 'BAN', 'SA', 'PAK', 'WI', None, 'SL', 'NZ', 'ICC'}
# {None, 'PAK', 'SL', 'SA'}
# {'BAN', 'ENG', 'SA', 'AFG', 'PAK', 'SL', 'NZ', 'ICC', 'ZIM', 'INDIA', 'WI', None, 'Afr', 'Asia', 'AUS'}
# 14

# %%
# 19. Which player(s) had played for the longest period of time?
new = df2["Period"].str.split("-", n = 1, expand = True)
# print(new)
a = new[0].astype(str).astype(int)
b = new[1].astype(str).astype(int)
index = (b-a).idxmax()
print(df2.iloc[index]["Player(Team)"])
# Out:
# SR Tendulkar (INDIA)

# %%
# 20. Which player(s) had played for the shortest period of time?
new = df2["Period"].str.split("-", n = 1, expand = True)
# print(new)
a = new[0].astype(str).astype(int)
b = new[1].astype(str).astype(int)
index = (b-a).idxmin()
print(df2.iloc[index]["Player(Team)"])
# Out:
# BKV Prasad (INDIA)

# %%
# 21. How many Australian Bowlers are present in this dataset?
count = df2["Player(Team)"].str.contains("AUS").sum()
count
# Out:
# 10

# %%
# 22. Is there any Bangladeshi player present in this dataset?
count = df2["Player(Team)"].str.contains("BAN").sum()
c = bool(count)
print(c)
# Out:
# True

# %%
# 23. Which player had the lowest economy rate?
index = df2["Economy"].idxmin()
print(df2.iloc[index]["Player(Team)"])
# Out:
# RJ Hadlee (NZ)

# %%
# 24. Which player had the lowest strike rate?
index = df2["Strike Rate"].idxmin()
print(df2.iloc[index]["Player(Team)"])
# Out:
# MA Starc (AUS)

# %%
# 25. Which player had the lowest bowling average?
index = df2["Average"].idxmin()
print(df2.iloc[index]["Player(Team)"])
# Out:
# Rashid Khan (AFG)

# %%
# 26. Remove Unnecessary columns if needed.
df3 = df2.drop(["4 Wickets","5 Wickets","Matches","Innings","Balls","Runs","Wickets"],axis=1)
print(df3)
# Out:
#                     Player(Team)     Period  Average  Economy  Strike Rate
# 0   M Muralitharan (Asia/ICC/SL)  1993-2011    23.08     3.93         35.2
# 1              Wasim Akram (PAK)  1984-2003    23.52     3.89         36.2
# 2             Waqar Younis (PAK)  1989-2003    23.84     4.68         30.5
# 3           WPUJC Vaas (Asia/SL)  1994-2008    27.53     4.18         39.4
# 4   Shahid Afridi (Asia/ICC/PAK)  1996-2015    34.51     4.62         44.7
# ..                           ...        ...      ...      ...          ...
# 72          SR Tendulkar (INDIA)  1989-2012    44.48     5.10         52.2
# 73               BAW Mendis (SL)  2008-2015    21.86     4.80         27.3
# 74             Rashid Khan (AFG)  2015-2022    18.68     4.15         26.9
# 75             UDU Chandana (SL)  1994-2007    31.90     4.70         40.6
# 76              R Ashwin (INDIA)  2010-2022    33.49     4.94         40.6
#
# [77 rows x 5 columns]

# %% [markdown]
#                                                          THANK YOU
